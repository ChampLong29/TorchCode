# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/50_gae.ipynb)
#
# #  Hard: GAE (Generalized Advantage Estimation)
#
# Implement **GAE** — the standard advantage estimator in PPO, the workhorse of modern RL training for LLM agents.
#
# ### Signature
# ```python
# def compute_gae(rewards, values, dones, gamma=0.99, lam=0.95):
#     """Compute Generalized Advantage Estimation.
#     Args:
#         rewards: (T,) tensor of step rewards
#         values: (T+1,) tensor of value estimates (includes V_T bootstrap)
#         dones: (T,) bool tensor, True at terminal steps
#         gamma: discount factor
#         lam: GAE lambda (0=TD(0), 1=MC returns, 0.95 typical)
#     Returns:
#         advantages: (T,) tensor
#         returns: (T,) tensor = advantages + values[:-1]
#     """
#     ...
# ```
#
# ### Math
# ```
# delta_t = r_t + gamma * V(t+1) * (1-done_t) - V(t)
# A_t = delta_t + gamma * lambda * (1-done_t) * A_(t+1)
# G_t = A_t + V(t)
# ```
#
# ### Interview Context
# "Why GAE lambda between TD and MC?" → Lambda=0 gives low-variance biased TD(0),
# lambda=1 gives high-variance unbiased MC. Lambda=0.95 balances bias-variance tradeoff.
# Interviews test understanding of the reverse-loop computation (O(T), not O(T^2)).

# %%
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
#  YOUR IMPLEMENTATION HERE

def compute_gae(rewards, values, dones, gamma=0.99, lam=0.95):
    """Compute Generalized Advantage Estimation."""
    pass

# %%
#  Test
r = torch.tensor([1.0, 1.0, 1.0])
v = torch.zeros(4)
d = torch.zeros(3, dtype=torch.bool)
adv, ret = compute_gae(r, v, d, gamma=0.99, lam=0.0)
print("Advantages:", adv, "Returns:", ret)
assert torch.allclose(adv, r)
print(" Passed!")

# %%
from torch_judge import check
check("gae")
