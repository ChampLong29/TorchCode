# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/54_planning.ipynb)
#
# #  Hard: Planning & Self-Correction Loop
#
# Implement a **plan-then-execute loop** with self-correction — plan a sequence of steps, execute them, detect failures, and re-plan.
#
# ### Signature
# ```python
# def planning_execute_loop(task, planner_fn, executor_fn,
#                          max_retries=3, verifier_fn=None):
#     """Plan-then-execute with self-correction.
#     Args:
#         task: str, task description
#         planner_fn: callable(task, context) -> List[str] steps
#         executor_fn: callable(step, context) -> {"result": Any, "success": bool}
#         max_retries: max retries per failed step
#         verifier_fn: optional callable(result, expected) -> bool
#     Returns:
#         (final_result, trace) where trace is list of execution records
#     """
#     ...
# ```
#
# ### Interview Context
# "What happens when an agent makes a mistake?" → Self-correction: detect error,
# analyze cause, replan remaining steps. DeepSeek-R1 uses rejection sampling for
# incorrect trajectories. Reflexion (Shinn et al.) uses verbal self-reflection.
# Tree-of-Thought (Yao et al.) backtracks and explores alternative branches.

# %%
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
#  YOUR IMPLEMENTATION HERE

def planning_execute_loop(task, planner_fn, executor_fn,
                         max_retries=3, verifier_fn=None):
    """Plan-then-execute with self-correction."""
    pass

# %%
#  Test
def planner(task, ctx):
    return ["step_1", "step_2", "step_3"]
def executor(step, ctx):
    return {"result": f"done_{step}", "success": True}
result, trace = planning_execute_loop("task", planner, executor)
print(f"{len(trace)} steps executed")
assert result["success"]
print(" Passed!")

# %%
from torch_judge import check
check("planning")
