# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/52_context_memory.ipynb)
#
# #  Medium: Context Window Memory Manager
#
# Manage the agent's **context window** — when the conversation grows beyond the token budget, decide what to keep, compress, or drop.
#
# ### Signature
# ```python
# def manage_context(history, new_observation, max_tokens=4096,
#                   token_counter=None, strategy="sliding"):
#     """Manage agent context memory.
#     Args:
#         history: list of {"role": str, "content": str}
#         new_observation: str, latest observation to include
#         max_tokens: token budget
#         token_counter: callable(text) -> int
#         strategy: "sliding" | "truncate" | "summarize"
#     Returns:
#         updated context fitting within token budget
#     """
#     ...
# ```
#
# ### Interview Context
# "What happens when the context exceeds the model's max length?"
# → Strategies: (1) Sliding window: keep last N tokens. (2) Truncate oldest: drop oldest
# messages while preserving system prompt. (3) Summarize: compress old messages.
# Real-world: MemGPT, Letta use OS-style memory management for LLM context.

# %%
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
#  YOUR IMPLEMENTATION HERE

def manage_context(history, new_observation, max_tokens=4096,
                  token_counter=None, strategy="sliding"):
    """Manage agent context memory."""
    pass

# %%
#  Test
history = [
    {"role": "system", "content": "You are helpful."},
    {"role": "user", "content": "What is 2+2?"},
    {"role": "assistant", "content": "It is 4."},
]
result = manage_context(history, "Thanks!", max_tokens=80,
                        token_counter=len, strategy="truncate")
print(f"{len(history)} -> {len(result)} messages")
assert len(result) >= 1
print(" Passed!")

# %%
from torch_judge import check
check("context_memory")
