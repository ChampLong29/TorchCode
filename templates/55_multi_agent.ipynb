# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/55_multi_agent.ipynb)
#
# #  Hard: Multi-Agent Message Router
#
# Implement a **message router** for multi-agent systems — route messages between agents, support broadcast and multi-target delivery.
#
# ### Signature
# ```python
# def agent_message_router(message, agent_registry, routing_rules=None):
#     """Route messages between agents.
#     Args:
#         message: dict with keys:
#             "from": str, sender agent name
#             "to": str | List[str], recipient(s). "*" or "broadcast" sends to all
#             "content": Any, message payload
#             "type": str, message type for filtering
#         agent_registry: dict of {name: callable(message) -> response}
#         routing_rules: optional dict of {"type": [agent_names]} for type-based routing
#     Returns:
#         list of response dicts from each recipient
#     """
#     ...
# ```
#
# ### Interview Context
# "How do agents talk to each other?" → Message passing: structured protocol
# (like ROS or FIPA ACL). Broadcast to all, point-to-point, or type-based routing.
# Real-world: AutoGen (Microsoft), CrewAI, LangGraph multi-agent patterns.

# %%
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
#  YOUR IMPLEMENTATION HERE

def agent_message_router(message, agent_registry, routing_rules=None):
    """Route messages between agents."""
    pass

# %%
#  Test
agents = {
    "alice": lambda m: {"from": "alice", "response": f"Got: {m['content']}"},
    "bob": lambda m: {"from": "bob", "response": "ok"},
}
responses = agent_message_router(
    {"from": "alice", "to": "bob", "content": "hello", "type": "chat"},
    agents
)
print("Responses:", responses)
assert len(responses) == 1
assert responses[0]["from"] == "bob"
print(" Passed!")

# %%
from torch_judge import check
check("multi_agent")
