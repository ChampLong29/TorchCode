# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/45_pretrain_data.ipynb)
#
# #  Medium: Pretraining Data Cleaning
#
# Implement a **pretraining data cleaning pipeline**: filter, deduplicate, and normalize raw text data for LLM pretraining.
#
# ### Signature
# ```python
# def clean_pretrain_data(texts, min_length=50, max_length=2048,
#                         dedup_threshold=0.8, filter_repetitive=True):
#     """Clean pretraining text data.
#     Args:
#         texts: List[str], raw text samples
#         min_length: min character length
#         max_length: max character length
#         dedup_threshold: Jaccard similarity threshold for dedup (0-1)
#         filter_repetitive: if True, filter texts with high char repetition
#     Returns:
#         cleaned: List[str]
#     """
#     ...
# ```
#
# ### Rules
# - Filter texts shorter than `min_length` or longer than `max_length`
# - If `filter_repetitive`: remove texts where max single char frequency > 50%
# - Deduplicate near-duplicate pairs using n-gram (n=3) Jaccard similarity
# - Strip leading/trailing whitespace from each text
#
# ### Example
# ```python
# >>> texts = ["hi", "The quick brown fox...", "ok", "The quick brown cat...", "aaa...aaa"]
# >>> clean_pretrain_data(texts, min_length=10)
# ["The quick brown fox..."]  # short + repetitive texts removed, near-dup merged
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
#  YOUR IMPLEMENTATION HERE

def clean_pretrain_data(texts, min_length=50, max_length=2048,
                        dedup_threshold=0.8, filter_repetitive=True):
    """Clean pretraining text data."""
    pass  # Replace this

# %%
#  Test your implementation

texts = [
    "short",
    "This is a normal paragraph with enough characters to pass the min length filter.",
    "ok",
    "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa",  # repetitive
    "  Another valid text with trailing whitespace.  "
]

result = clean_pretrain_data(texts, min_length=10, max_length=512)
print(f"Input: {len(texts)} texts")
print(f"Output: {len(result)} texts")
for t in result:
    print(f"  '{t[:50]}...'")
assert len(result) == 2, f"Expected 2 cleaned texts, got {len(result)}"
print(" Passed!")

# %%
#  SUBMIT  Run this cell to check your solution
from torch_judge import check
check("pretrain_data")
