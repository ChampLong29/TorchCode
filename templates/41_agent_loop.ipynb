# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/41_agent_loop.ipynb)
#
# #  Medium: ReAct Agent Loop
#
# Implement a minimal **ReAct (Reasoning + Acting)** agent loop from scratch.
#
# The agent iterates through a Thought-Action-Observation cycle until it produces a Final Answer.
#
# ### Signature
# ```python
# def react_agent_loop(model_fn, tools, query, max_steps=5):
#     """Minimal ReAct agent loop.
#     Args:
#         model_fn: callable(prompt) -> response_str
#         tools: dict of {name: callable(args) -> result_str}
#         query: user query string
#         max_steps: max iterations
#     Returns:
#         final_answer: str or None if max_steps exceeded
#     """
#     ...
# ```
#
# ### Rules
# - Parse `Thought:`, `Action:`, `Action Input:`, and `Final Answer:` from model output
# - If model returns a tool call, execute the tool and feed result as Observation
# - If model returns `Final Answer:`, extract and return it
# - Stop and return None if `max_steps` reached without answer
# - Accumulate conversation history for context
#
# ### Example
# ```
# query: "What is the capital of France?"
#
# Step 1:
#   Thought: I need to look up France's capital
#   Action: lookup
#   Action Input: France
#   Observation: Paris
#
# Step 2:
#   Thought: I now know the answer
#   Final Answer: Paris
#
# Returns: "Paris"
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import re

# %%
#  YOUR IMPLEMENTATION HERE

def react_agent_loop(model_fn, tools, query, max_steps=5):
    """Minimal ReAct agent loop."""
    pass  # Replace this

# %%
#  Test your implementation
responses = iter([
    "Thought: Let me look this up.\nAction: search\nAction Input: capital of France",
    "Thought: The answer is clear.\nFinal Answer: Paris",
])
mock_model = lambda prompt: next(responses)
tools = {"search": lambda q: f"Result for '{q}': Paris is the capital of France."}

result = react_agent_loop(mock_model, tools, "capital of France?")
print("Result:", result)
assert result == "Paris", f"Expected 'Paris', got {result!r}"
print(" Passed!")

# %%
#  SUBMIT  Run this cell to check your solution
from torch_judge import check
check("agent_loop")
