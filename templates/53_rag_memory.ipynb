# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/53_rag_memory.ipynb)
#
# #  Medium: RAG Memory for Agents
#
# Implement **retrieval-augmented memory** — embed past experiences and retrieve the most relevant ones when facing a similar situation.
#
# ### Signature
# ```python
# def retrieve_relevant_memory(query, memory_store, embedding_fn, top_k=5):
#     """Retrieve relevant past experiences.
#     Args:
#         query: str, current context to find memories for
#         memory_store: list of {"embedding": (d,) tensor, "content": str, "metadata": dict}
#         embedding_fn: callable(text) -> (d,) tensor
#         top_k: number of memories to return
#     Returns:
#         list of top_k memory entries sorted by relevance score
#     """
#     ...
# ```
#
# ### Interview Context
# "How does an agent remember long-term?" → Embedding-based retrieval: encode
# past states/actions/outcomes, use cosine similarity for nearest-neighbor lookup.
# Bonus points: keyword matching boosts score. Real-world: Voyager (Minecraft agent),
# Generative Agents (Park et al.) use embedding-based memory retrieval.

# %%
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch

# %%
#  YOUR IMPLEMENTATION HERE

def retrieve_relevant_memory(query, memory_store, embedding_fn, top_k=5):
    """Retrieve relevant past experiences."""
    pass

# %%
#  Test
def emb(text):
    return {"cat": torch.tensor([1.,0.,0.]), "dog": torch.tensor([0.,1.,0.])}.get(text, torch.zeros(3))
store = [
    {"embedding": emb("cat"), "content": "cat content", "metadata": {"id": 1}},
    {"embedding": emb("dog"), "content": "dog content", "metadata": {"id": 2}},
]
results = retrieve_relevant_memory("cat", store, emb, top_k=1)
print("Top result:", results[0]["metadata"])
assert results[0]["metadata"]["id"] == 1
print(" Passed!")

# %%
from torch_judge import check
check("rag_memory")
